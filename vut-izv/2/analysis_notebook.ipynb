# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import os

# %%
# Ukol3: příčina nehody a škoda
def plot_damage(df: pd.DataFrame, fig_location: str = None,
                show_figure: bool = False):
    plt.ioff()
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, constrained_layout=True, figsize=(10,10))
    fig.suptitle("Následky nehod v jednotlivých regionech")
    
    sns.set_theme()

    df_agg_jhm = df.groupby(["region"]).agg({"p13a": "sum"})
    df_agg_jhm.reset_index(inplace=True)
    sns.barplot(ax=ax1, x="region", y="p13a", data=df_agg_a.sort_values("p13a", ascending=False))
    ax1.set_title("Počet úmrtí při nehodách")
    ax1.set_xlabel("Regiony")
    ax1.set_ylabel("Počet úmrtí")

    df_agg_a = df.groupby(["region"]).agg({"p13a": "sum"})
    df_agg_a.reset_index(inplace=True)
    sns.barplot(ax=ax2, x="region", y="p13a", data=df_agg_a.sort_values("p13a", ascending=False))
    ax2.set_title("Počet úmrtí při nehodách")
    ax2.set_xlabel("Regiony")
    ax2.set_ylabel("Počet úmrtí")

    df_agg_a = df.groupby(["region"]).agg({"p13a": "sum"})
    df_agg_a.reset_index(inplace=True)
    sns.barplot(ax=ax3, x="region", y="p13a", data=df_agg_a.sort_values("p13a", ascending=False))
    ax3.set_title("Počet úmrtí při nehodách")
    ax3.set_xlabel("Regiony")
    ax3.set_ylabel("Počet úmrtí")

    df_agg_a = df.groupby(["region"]).agg({"p13a": "sum"})
    df_agg_a.reset_index(inplace=True)
    sns.barplot(ax=ax4, x="region", y="p13a", data=df_agg_a.sort_values("p13a", ascending=False))
    ax4.set_title("Počet úmrtí při nehodách")
    ax4.set_xlabel("Regiony")
    ax4.set_ylabel("Počet úmrtí")


    if show_figure:
        plt.show

# %%
plot_damage(df, "02_priciny.png", True)

# %%
# Ukol 2: následky nehod v jednotlivých regionech
def plot_conseq(df: pd.DataFrame, fig_location: str = None, show_figure: bool = False):
    plt.ioff()
    fig, axes = plt.subplots(4,1, constrained_layout=True, figsize=(10,10))
    fig.suptitle("Následky nehod v jednotlivých regionech")
    
    sns.set_theme()

    df_agg_a = df.groupby(["region"]).agg({"p13a": "sum"})
    df_agg_a.reset_index(inplace=True)
    sns.barplot(ax=axes[0], x="region", y="p13a", data=df_agg_a.sort_values("p13a", ascending=False), palette="Reds_r")
    axes[0].set_title("Počet úmrtí při nehodách")
    axes[0].set_xlabel("Regiony")
    axes[0].set_ylabel("Počet úmrtí")

    df_agg_b = df.groupby(["region"]).agg({"p13b": "sum"})
    df_agg_b.reset_index(inplace=True)
    sns.barplot(ax=axes[1], x="region", y="p13b", data=df_agg_b.sort_values("p13b", ascending=False), palette="Reds_r")
    axes[1].set_title("Počet těžce zraněných")
    axes[1].set_xlabel("Regiony")
    axes[1].set_ylabel("Počet zraněných")

    df_agg_c = df.groupby(["region"]).agg({"p13c": "sum"})
    df_agg_c.reset_index(inplace=True)
    sns.barplot(ax=axes[2], x="region", y="p13c", data=df_agg_c.sort_values("p13c", ascending=False), palette="Reds_r")
    axes[2].set_title("Počet lehce zraněných")
    axes[2].set_xlabel("Regiony")
    axes[2].set_ylabel("Počet zraněných")

    sns.countplot(ax=axes[3], x="region", data=df, order=df["region"].value_counts().index, palette="Reds_r")
    axes[3].set_title("Celkový počet nehod")
    axes[3].set_xlabel("Regiony")
    axes[3].set_ylabel("Počet nehod")

    plt.savefig(fig_location)

    if show_figure:
        plt.show()

# %%
    # zde je ukazka pouziti, tuto cast muzete modifikovat podle libosti
    # skript nebude pri testovani pousten primo, ale budou volany konkreni ¨
    # funkce.

    df = get_dataframe("accidents.pkl.gz",True)

    #plot_conseq(df, fig_location="01_nasledky.png", show_figure=False)
    plot_damage(df, "02_priciny.png", True)
    #plot_surface(df, "03_stav.png", True)
# Out:
# orig_size=715.7 MB
# new_size=167.4 MB

# %%
df
# Out:
#                   p1 p36   p37       date weekday(p2a)   p2b p6  p7  p8  p9  \
# 0       002100160001   4       2016-01-01            5  0055  1   1   0   2
# 1       002100160002   4       2016-01-01            5  0130  1   3   0   2
# 2       002100160003   5       2016-01-01            5  0100  1   2   0   2
# 3       002100160004   6       2016-01-01            5  0120  9   0   0   2
# 4       002100160005   6       2016-01-01            5  2560  2   0   0   2
# ...              ...  ..   ...        ...          ...   ... ..  ..  ..  ..
# 487156  190906200498   6       2020-09-29            2  2560  2   0   0   2
# 487157  190906200499   0     6 2020-09-29            2  1940  1   2   0   2
# 487158  190906200500   3  2114 2020-09-30            3  2045  1   4   0   2
# 487159  190906200501   0     6 2020-10-01            4  0420  3   0   4   2
# 487160  190906200502   6       2020-10-01            4  2560  2   0   0   2
#
#         ...     l        n  o                       p       q       r       s  \
# 0       ...         711403     Souhlasnýsesměremúseku  Pomalý  554782  451622
# 1       ...
# 2       ...
# 3       ...
# 4       ...
# ...     ...   ...      ... ..                     ...     ...     ...     ...
# 487156  ...        3438492     Souhlasnýsesměremúseku  Pomalý  560294
# 487157  ...    D6  1671277     Souhlasnýsesměremúseku  Pomalý  560286
# 487158  ...  2114  1669033         Opačnýkesměruúseku  Pomalý  554642
# 487159  ...    D6  3513947     Souhlasnýsesměremúseku  Pomalý  560294
# 487160  ...        3704381     Souhlasnýsesměremúseku  Pomalý  560383
#
#                          t  p5a  region
# 0       GN_V0.1UIR-ADR_410    1     PHA
# 1                             1     PHA
# 2                             1     PHA
# 3                             1     PHA
# 4                             1     PHA
# ...                    ...  ...     ...
# 487156  GN_V0.1UIR-ADR_410    1     KVK
# 487157  GN_V0.1UIR-ADR_410    2     KVK
# 487158  GN_V0.1UIR-ADR_410    2     KVK
# 487159  GN_V0.1UIR-ADR_410    2     KVK
# 487160  GN_V0.1UIR-ADR_410    1     KVK
#
# [487161 rows x 65 columns]

# %%
# Ukol 1: nacteni dat
def get_dataframe(filename: str, verbose: bool = False) -> pd.DataFrame:
    # check if file exists
    if os.path.exists(filename) and os.path.isfile(filename):
        # create dataframe and fill it
        df = pd.read_pickle(filename)
        if verbose:
            # print original dataframe size
            print(f'orig_size={np.round(df.memory_usage(deep=True).sum() / 1048576, 1)} MB')
        # go through every series of dataframe and 
        for col_name, col_data in df.iteritems():
            # column is int
            if df[col_name].dtype == np.int32:
                # check if max value in column can be byte
                if df[col_name].max() < 128 and df[col_name].min() > -128:
                    # set dtype of column to int8 for memory savings
                    df[col_name] = df[col_name].astype("int8")
            # column is date column
            elif col_name == "p2a":
                # make it datetime64 format
                df[col_name] = df[col_name].astype('datetime64')
                # rename it
                df = df.rename(columns={col_name: "date"})
            # column is region, don't change anything
            elif col_name == "region":
                pass
            # column is type object
            elif df[col_name].dtype == np.object:
                # make it category for memory savings
                df[col_name] = df[col_name].astype('category')
        if verbose:
            # print changed dataframe size
            print(f'new_size={np.round(df.memory_usage(deep=True).sum() / 1048576, 1)} MB')
        # return data
        return df
